# 1253  12/23/2016  790.90  792.74  787.28  789.91     623,400
# 1254  12/27/2016  790.68  797.86  787.66  791.55     789,100
# 1255  12/28/2016  793.70  794.23  783.20  785.05   1,153,800
# 1256  12/29/2016  783.33  785.93  778.92  782.79     744,300
# 1257  12/30/2016  782.75  782.78  770.41  771.82   1,770,000
#
# [1258 rows x 6 columns]

# %%
training_set = dataset_train.iloc[:,1:2].values

# %%
# Feature scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range =(0,1))

# %%
training_set_scaled = sc.fit_transform(training_set)

# %%
training_set_scaled
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
X_train[1]
# Out:
# array([0.09701243, 0.09433366, 0.09156187, 0.07984225, 0.0643277 ,
#        0.0585423 , 0.06568569, 0.06109085, 0.06639259, 0.0614257 ,
#        0.07474514, 0.02797827, 0.02379269, 0.02409033, 0.0159238 ,
#        0.01078949, 0.00967334, 0.01642607, 0.02100231, 0.02280676,
#        0.02273235, 0.02810849, 0.03212665, 0.0433812 , 0.04475779,
#        0.04790163, 0.0440695 , 0.04648783, 0.04745517, 0.04873875,
#        0.03936305, 0.04137213, 0.04034898, 0.04784582, 0.04325099,
#        0.04356723, 0.04286033, 0.04602277, 0.05398467, 0.05738894,
#        0.05714711, 0.05569611, 0.04421832, 0.04514845, 0.04605997,
#        0.04412531, 0.03675869, 0.04486941, 0.05065481, 0.05214302,
#        0.05612397, 0.05818885, 0.06540665, 0.06882953, 0.07243843,
#        0.07993526, 0.07846566, 0.08034452, 0.08497656, 0.08627874])

# %%
X_train.shape[1]
# Out:
# 60

# %%
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Part -2 - Building the RNN
# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
# Out:
# Using TensorFlow backend.

# %%
# Initialising the RNN
regressor = Sequential()

# %%
# Adding the first LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# %%
# Adding a second LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
# Adding a third LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# %%
# Adding a fourth LSTM layer and some Dropout regularisation
regressor.add(LSTM(units = 50))
regressor.add(Dropout(0.2))

# %%
# Adding the output layer
regressor.add(Dense(units = 1))

# %%
regressor.compile(optimizer = 'adam', loss = 'mean_squared_error',metrics=['accuracy'])

# %%
regressor.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_13 (LSTM)               (None, 60, 50)            10400
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 60, 50)            0
# _________________________________________________________________
# lstm_14 (LSTM)               (None, 60, 50)            20200
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 60, 50)            0
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 60, 50)            20200
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 60, 50)            0
# _________________________________________________________________
# lstm_16 (LSTM)               (None, 50)                20200
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 71,051
# Trainable params: 71,051
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting the RNN to the Training set
regressor.fit(X_train, y_train, epochs = 50, batch_size = 32,verbose=1)
# Out:
# Epoch 1/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0023 - accuracy: 0.0017
# Epoch 2/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0024 - accuracy: 0.0017
# Epoch 3/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0025 - accuracy: 0.0017
# Epoch 4/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0023 - accuracy: 0.0017
# Epoch 5/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 6/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0025 - accuracy: 0.0017: 3s - ETA: 0s - loss: 0.0025 - accuracy: 0.00
# Epoch 7/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0023 - accuracy: 0.0017
# Epoch 8/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0023 - accuracy: 0.0017
# Epoch 9/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0024 - accuracy: 0.0017
# Epoch 10/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0020 - accuracy: 0.0017
# Epoch 11/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 12/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 13/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 14/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0020 - accuracy: 0.0017: 1s - loss: 0.0020
# Epoch 15/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 16/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0020 - accuracy: 0.0017: 2s - loss: 0
# Epoch 17/50
# 1198/1198 [==============================] - 8s 6ms/step - loss: 0.0021 - accuracy: 0.0017
# Epoch 18/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0020 - accuracy: 0.0017
# Epoch 19/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0022 - accuracy: 0.0017
# Epoch 20/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0020 - accuracy: 0.0017
# Epoch 21/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0021 - accuracy: 0.0017
# Epoch 22/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 23/50
# 1198/1198 [==============================] - 7s 6ms/step - loss: 0.0021 - accuracy: 0.0017
# Epoch 24/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 25/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 26/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0021 - accuracy: 0.0017
# Epoch 27/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 28/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 29/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 30/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 31/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 32/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 33/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0019 - accuracy: 0.0017
# Epoch 34/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 35/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0018 - accuracy: 0.0017
# Epoch 36/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 37/50
# 1198/1198 [==============================] - 5s 5ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 38/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 39/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 40/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 41/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0014 - accuracy: 0.0017
# Epoch 42/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0013 - accuracy: 0.0017
# Epoch 43/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 44/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 45/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0017 - accuracy: 0.0017
# Epoch 46/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 47/50
# 1198/1198 [==============================] - 5s 4ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 48/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0015 - accuracy: 0.0017
# Epoch 49/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0016 - accuracy: 0.0017
# Epoch 50/50
# 1198/1198 [==============================] - 6s 5ms/step - loss: 0.0017 - accuracy: 0.0017

# %%
# Part 3 - Making the predictions and visualising the results

# Getting the real stock price of 2017
dataset_test = pd.read_csv('Google_Stock_Price_Test.csv')

# %%
dataset_test
# Out:
#          Date    Open    High     Low   Close     Volume
# 0    1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1    1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2    1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3    1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4    1/9/2017  806.40  809.97  802.83  806.65  1,272,400
# 5   1/10/2017  807.86  809.13  803.51  804.79  1,176,800
# 6   1/11/2017  805.00  808.15  801.37  807.91  1,065,900
# 7   1/12/2017  807.14  807.39  799.17  806.36  1,353,100
# 8   1/13/2017  807.48  811.22  806.69  807.88  1,099,200
# 9   1/17/2017  807.08  807.14  800.37  804.61  1,362,100
# 10  1/18/2017  805.81  806.21  800.99  806.07  1,294,400
# 11  1/19/2017  805.12  809.48  801.80  802.17    919,300
# 12  1/20/2017  806.91  806.91  801.69  805.02  1,670,000
# 13  1/23/2017  807.25  820.87  803.74  819.31  1,963,600
# 14  1/24/2017  822.30  825.90  817.82  823.87  1,474,000
# 15  1/25/2017  829.62  835.77  825.06  835.67  1,494,500
# 16  1/26/2017  837.81  838.00  827.01  832.15  2,973,900
# 17  1/27/2017  834.71  841.95  820.44  823.31  2,965,800
# 18  1/30/2017  814.66  815.84  799.80  802.32  3,246,600
# 19  1/31/2017  796.86  801.25  790.52  796.79  2,160,600

# %%
real_stock_price = dataset_test.iloc[:,1:2].values

# %%
real_stock_price
# Out:
# array([[778.81],
#        [788.36],
#        [786.08],
#        [795.26],
#        [806.4 ],
#        [807.86],
#        [805.  ],
#        [807.14],
#        [807.48],
#        [807.08],
#        [805.81],
#        [805.12],
#        [806.91],
#        [807.25],
#        [822.3 ],
#        [829.62],
#        [837.81],
#        [834.71],
#        [814.66],
#        [796.86]])

# %%
# Getting the predicted stock price of 2017
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)

# %%
dataset_total
# Out:
# 0       325.25
# 1       331.27
# 2       329.83
# 3       328.34
# 4       322.04
# 5       313.70
# 6       310.59
# 7       314.43
# 8       311.96
# 9       314.81
# 10      312.14
# 11      319.30
# 12      294.16
# 13      291.91
# 14      292.07
# 15      287.68
# 16      284.92
# 17      284.32
# 18      287.95
# 19      290.41
# 20      291.38
# 21      291.34
# 22      294.23
# 23      296.39
# 24      302.44
# 25      303.18
# 26      304.87
# 27      302.81
# 28      304.11
# 29      304.63
#          ...
# 1248    800.40
# 1249    790.22
# 1250    796.76
# 1251    795.84
# 1252    792.36
# 1253    790.90
# 1254    790.68
# 1255    793.70
# 1256    783.33
# 1257    782.75
# 0       778.81
# 1       788.36
# 2       786.08
# 3       795.26
# 4       806.40
# 5       807.86
# 6       805.00
# 7       807.14
# 8       807.48
# 9       807.08
# 10      805.81
# 11      805.12
# 12      806.91
# 13      807.25
# 14      822.30
# 15      829.62
# 16      837.81
# 17      834.71
# 18      814.66
# 19      796.86
# Name: Open, Length: 1278, dtype: float64

# %%
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values

# %%
inputs
# Out:
# array([779.  , 779.66, 777.71, 786.66, 783.76, 781.22, 781.65, 779.8 ,
#        787.85, 798.24, 803.3 , 795.  , 804.9 , 816.68, 806.34, 801.  ,
#        808.35, 795.47, 782.89, 778.2 , 767.25, 750.66, 774.5 , 783.4 ,
#        779.94, 791.17, 756.54, 755.6 , 746.97, 755.2 , 766.92, 771.37,
#        762.61, 772.63, 767.73, 764.26, 760.  , 771.53, 770.07, 757.44,
#        744.59, 757.71, 764.73, 761.  , 772.48, 780.  , 785.04, 793.9 ,
#        797.4 , 797.34, 800.4 , 790.22, 796.76, 795.84, 792.36, 790.9 ,
#        790.68, 793.7 , 783.33, 782.75, 778.81, 788.36, 786.08, 795.26,
#        806.4 , 807.86, 805.  , 807.14, 807.48, 807.08, 805.81, 805.12,
#        806.91, 807.25, 822.3 , 829.62, 837.81, 834.71, 814.66, 796.86])

# %%
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)

# %%
inputs
# Out:
# array([[0.9299055 ],
#        [0.93113327],
#        [0.92750577],
#        [0.94415507],
#        [0.93876032],
#        [0.93403527],
#        [0.93483518],
#        [0.9313937 ],
#        [0.94636878],
#        [0.96569685],
#        [0.97510976],
#        [0.95966962],
#        [0.97808617],
#        [1.        ],
#        [0.98076494],
#        [0.97083116],
#        [0.98450406],
#        [0.96054394],
#        [0.9371419 ],
#        [0.92841729],
#        [0.90804747],
#        [0.8771858 ],
#        [0.92153434],
#        [0.93809063],
#        [0.93165414],
#        [0.95254483],
#        [0.88812412],
#        [0.88637547],
#        [0.87032145],
#        [0.88563137],
#        [0.90743359],
#        [0.91571173],
#        [0.89941588],
#        [0.91805566],
#        [0.9089404 ],
#        [0.9024853 ],
#        [0.89456061],
#        [0.91600938],
#        [0.9132934 ],
#        [0.88979835],
#        [0.86589404],
#        [0.89030062],
#        [0.90335962],
#        [0.89642086],
#        [0.91777662],
#        [0.93176576],
#        [0.94114145],
#        [0.95762334],
#        [0.96413424],
#        [0.96402262],
#        [0.96971501],
#        [0.95077759],
#        [0.96294367],
#        [0.96123223],
#        [0.95475854],
#        [0.95204256],
#        [0.95163331],
#        [0.95725128],
#        [0.93796041],
#        [0.93688146],
#        [0.92955205],
#        [0.94731751],
#        [0.94307612],
#        [0.96015329],
#        [0.98087655],
#        [0.98359253],
#        [0.97827219],
#        [0.98225314],
#        [0.98288563],
#        [0.98214153],
#        [0.979779  ],
#        [0.97849542],
#        [0.98182528],
#        [0.98245777],
#        [1.01045465],
#        [1.02407173],
#        [1.03930724],
#        [1.03354044],
#        [0.99624228],
#        [0.9631297 ]])

# %%
X_test = []

# %%
for i in range(60, 80):
    X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
real_stock_price
# Out:
# array([[778.81],
#        [788.36],
#        [786.08],
#        [795.26],
#        [806.4 ],
#        [807.86],
#        [805.  ],
#        [807.14],
#        [807.48],
#        [807.08],
#        [805.81],
#        [805.12],
#        [806.91],
#        [807.25],
#        [822.3 ],
#        [829.62],
#        [837.81],
#        [834.71],
#        [814.66],
#        [796.86]])

# %%
# Visualising the results
plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
X_test[0]
# Out:
# array([[0.9299055 ],
#        [0.93113327],
#        [0.92750577],
#        [0.94415507],
#        [0.93876032],
#        [0.93403527],
#        [0.93483518],
#        [0.9313937 ],
#        [0.94636878],
#        [0.96569685],
#        [0.97510976],
#        [0.95966962],
#        [0.97808617],
#        [1.        ],
#        [0.98076494],
#        [0.97083116],
#        [0.98450406],
#        [0.96054394],
#        [0.9371419 ],
#        [0.92841729],
#        [0.90804747],
#        [0.8771858 ],
#        [0.92153434],
#        [0.93809063],
#        [0.93165414],
#        [0.95254483],
#        [0.88812412],
#        [0.88637547],
#        [0.87032145],
#        [0.88563137],
#        [0.90743359],
#        [0.91571173],
#        [0.89941588],
#        [0.91805566],
#        [0.9089404 ],
#        [0.9024853 ],
#        [0.89456061],
#        [0.91600938],
#        [0.9132934 ],
#        [0.88979835],
#        [0.86589404],
#        [0.89030062],
#        [0.90335962],
#        [0.89642086],
#        [0.91777662],
#        [0.93176576],
#        [0.94114145],
#        [0.95762334],
#        [0.96413424],
#        [0.96402262],
#        [0.96971501],
#        [0.95077759],
#        [0.96294367],
#        [0.96123223],
#        [0.95475854],
#        [0.95204256],
#        [0.95163331],
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
real_stock_price[0]
# Out:
# array([778.81])

# %%
X_test[0].shape
# Out:
# (60, 1)

# %%
sc.inverse_transform(regressor.predict(X_test[0].reshape(1,60,1)))
# Out:
# array([[766.18085]], dtype=float32)

# %%
list(zip(real_stock_price,predicted_stock_price))
# Out:
# [(array([778.81]), array([766.1809], dtype=float32)),
#  (array([788.36]), array([763.51855], dtype=float32)),
#  (array([786.08]), array([763.1026], dtype=float32)),
#  (array([795.26]), array([764.13855], dtype=float32)),
#  (array([806.4]), array([767.1646], dtype=float32)),
#  (array([807.86]), array([772.6408], dtype=float32)),
#  (array([805.]), array([778.2005], dtype=float32)),
#  (array([807.14]), array([781.1533], dtype=float32)),
#  (array([807.48]), array([781.8903], dtype=float32)),
#  (array([807.08]), array([781.52716], dtype=float32)),
#  (array([805.81]), array([780.9421], dtype=float32)),
#  (array([805.12]), array([780.44366], dtype=float32)),
#  (array([806.91]), array([780.18115], dtype=float32)),
#  (array([807.25]), array([780.6167], dtype=float32)),
#  (array([822.3]), array([781.5582], dtype=float32)),
#  (array([829.62]), array([785.5048], dtype=float32)),
#  (array([837.81]), array([791.90125], dtype=float32)),
#  (array([834.71]), array([799.2505], dtype=float32)),
#  (array([814.66]), array([804.00977], dtype=float32)),
#  (array([796.86]), array([801.5161], dtype=float32))]

# %%
list(zip(real_stock_price,))

# %% [markdown]
# ## Congratulation...!!!!! Awesome prediction .... We are very close to the real google stock price.
